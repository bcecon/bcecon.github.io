# %% [markdown]
# ---
# title: "NBA"
# author: "Byeong-Hak Choe"
# date: "2024-02-15"  #  Use the format YYYY-MM-DD
# categories: [python, data-analysis, nba]
# image: "image.jpeg"
# ---

# %% [markdown]
# # Data Loading and Preliminary Exploration
#
# First, we loaded the NBA dataset and observed its structure. The dataset contains five columns: `Name`, `Team`, `Position`, `Birthday`, and `Salary`. This gives us a good starting point to explore various aspects of the data, such as salary distributions among teams, age distribution of players, and more.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from itables import init_notebook_mode
from itables import show

nba = pd.read_csv("https://bcdanl.github.io/data/nfl.csv")
show(nba)
# Out:
# <div class="itables">
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables { font-size: medium; }
# </style>
# <table id="itables_5b8037d8_a9cb_445a_94fb_68d83fc6a74d" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Name</th>
#       <th>Team</th>
#       <th>Position</th>
#       <th>Birthday</th>
#       <th>Salary</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody>
#
# </table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     $(document).ready(function () {
#         document.querySelectorAll("#itables_5b8037d8_a9cb_445a_94fb_68d83fc6a74d:not(.dataTable)").forEach(table => {
#             // Define the table data
#             const data = [["Tremon Smith", "Philadelphia Eagles", "RB", "7/20/1996", 570000], ["Shawn Williams", "Cincinnati Bengals", "SS", "5/13/1991", 3500000], ["Adam Butler", "New England Patriots", "DT", "4/12/1994", 645000], ["Derek Wolfe", "Denver Broncos", "DE", "2/24/1990", 8000000], ["Jake Ryan", "Jacksonville Jaguars", "OLB", "2/27/1992", 1000000], ["Ezekiel Elliott", "Dallas Cowboys", "RB", "7/22/1995", 3853137], ["John Jenkins", "Miami Dolphins", "DE", "7/11/1989", 805000], ["Andrew Wingard", "Jacksonville Jaguars", "FS", "12/5/1996", 495000], ["John Jerry", "Cincinnati Bengals", "OT", "6/14/1986", 930000], ["Matt Barkley", "Buffalo Bills", "QB", "9/8/1990", 1250000], ["Josh Harris", "Atlanta Falcons", "LS", "4/27/1989", 930000], ["Adarius Taylor", "Cleveland Browns", "OLB", "9/21/1990", 1350000], ["Olabisi Johnson", "Minnesota Vikings", "WR", "3/17/1997", 647500], ["Andrew Adams", "Tampa Bay Buccaneers", "SS", "10/28/1992", 720000], ["Forrest Lamp", "Los Angeles Chargers", "G", "2/20/1994", 1071084], ["Ryan Kerrigan", "Washington Redskins", "OLB", "8/16/1988", 10500000], ["Robert Davis", "Philadelphia Eagles", "WR", "4/2/1995", 570000], ["Kevin Byard", "Tennessee Titans", "FS", "8/17/1993", 2025000], ["Pat O'Donnell", "Chicago Bears", "P", "2/22/1991", 1250000], ["Barkevious Mingo", "Houston Texans", "OLB", "10/4/1990", 3400000], ["Kylie Fitts", "Arizona Cardinals", "OLB", "10/11/1994", 570000], ["Akeem Spence", "Jacksonville Jaguars", "DT", "11/29/1991", 2900000], ["Javon Wims", "Chicago Bears", "WR", "9/11/1994", 570000], ["Ronnie Stanley", "Baltimore Ravens", "OT", "3/18/1994", 3243318], ["Jahleel Addae", "Houston Texans", "SS", "1/24/1990", 805000], ["Sony Michel", "New England Patriots", "RB", "2/17/1995", 917577], ["Melvin Ingram", "Los Angeles Chargers", "DE", "4/26/1989", 17000000], ["Julian Edelman", "New England Patriots", "WR", "5/22/1986", 1000000], ["Ted Ginn", "New Orleans Saints", "WR", "4/12/1985", 2500000], ["Romeo Okwara", "Detroit Lions", "DE", "6/17/1995", 720000], ["Corey Davis", "Tennessee Titans", "WR", "1/11/1995", 645000], ["Malcolm Jenkins", "Philadelphia Eagles", "SS", "12/20/1987", 8100000], ["Tyler Matakevich", "Pittsburgh Steelers", "ILB", "12/22/1992", 720000], ["D.J. Reed", "San Francisco 49Ers", "CB", "11/11/1996", 570000], ["Darius Slayton", "New York Giants", "WR", "1/12/1997", 495000], ["Bronson Kaufusi", "New York Jets", "DE", "7/6/1991", 645000], ["Colby Wadman", "Denver Broncos", "P", "4/19/1995", 570000], ["Frank Herron", "Detroit Lions", "DE", "9/9/1994", 495000], ["Ty Sambrailo", "Atlanta Falcons", "OT", "3/10/1992", 2000000], ["Alvin Kamara", "New Orleans Saints", "RB", "7/25/1995", 807500], ["Ka'dar Hollman", "Green Bay Packers", "CB", "9/18/1994", 672500], ["Brynden Trawick", "Baltimore Ravens", "FS", "10/23/1989", 805000], ["Stephone Anthony", "New Orleans Saints", "OLB", "7/28/1992", 805000], ["Neiko Thorpe", "Seattle Seahawks", "CB", "2/11/1990", 850000], ["Matthew Adams", "Indianapolis Colts", "OLB", "12/12/1995", 570000], ["Joel Bitonio", "Cleveland Browns", "G", "10/11/1991", 6500000], ["Jarius Wright", "Carolina Panthers", "WR", "11/25/1989", 1500000], ["Colin Jones", "Carolina Panthers", "FS", "10/27/1987", 930000], ["John Miller", "Cincinnati Bengals", "G", "8/12/1993", 900000], ["Rigoberto Sanchez", "Indianapolis Colts", "P", "9/8/1994", 645000], ["Taylor Stallworth", "New Orleans Saints", "NT", "8/18/1995", 570000], ["Dare Ogunbowale", "Tampa Bay Buccaneers", "RB", "5/4/1994", 495000], ["Adam Thielen", "Minnesota Vikings", "WR", "8/22/1990", 5850000], ["Tim Patrick", "Denver Broncos", "WR", "11/23/1993", 570000], ["Ryan Lewis", "Miami Dolphins", "CB", "4/15/1994", 570000], ["Jermaine Eluemunor", "New England Patriots", "G", "12/13/1994", 645000], ["Malik Reed", "Denver Broncos", "OLB", "8/5/1996", 495000], ["Marshal Yanda", "Baltimore Ravens", "G", "9/15/1984", 7000000], ["Cam Robinson", "Jacksonville Jaguars", "OT", "10/9/1995", 1103015], ["JJ Arcega-White ...

# %% [markdown]
# Let's start with checking out types of variables and missing values.

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1655 entries, 0 to 1654
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      1655 non-null   object
#  1   Team      1655 non-null   object
#  2   Position  1655 non-null   object
#  3   Birthday  1655 non-null   object
#  4   Salary    1655 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 64.8+ KB

# %% [markdown]
# # Data Cleaning
#
# Our initial peek at the data reveals some potential areas for cleaning:
# - Handling missing values, especially in the Salary column.
# - Converting the Birthday column to a datetime format to facilitate age calculations.

# %% [markdown]
# # Descriptive Statistics
# Let's take a look at the descriptive statistics.

# %%
nba.describe(include = "all")
# Out:
#                  Name           Team Position   Birthday        Salary
# count            1655           1655     1655       1655  1.655000e+03
# unique           1643             32       21       1316           NaN
# top     Ryan Anderson  New York Jets       WR  3/21/1995           NaN
# freq                3             58      183          6           NaN
# mean              NaN            NaN      NaN        NaN  1.861569e+06
# std               NaN            NaN      NaN        NaN  2.748519e+06
# min               NaN            NaN      NaN        NaN  3.780000e+05
# 25%               NaN            NaN      NaN        NaN  5.700000e+05
# 50%               NaN            NaN      NaN        NaN  8.000000e+05
# 75%               NaN            NaN      NaN        NaN  1.839952e+06
# max               NaN            NaN      NaN        NaN  2.750000e+07

# %% [markdown]
# # Data Analysis with Visualization

# %% [markdown]
# ## Salary Distribution Among Teams
# Let's start with the salary distribution among teams using seaborn for visualization. ​​

# %%
# Handle missing values in 'Salary' by replacing them with the median salary
median_salary = nba['Salary'].median()
nba['Salary'].fillna(median_salary, inplace=True)

# %%
# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Calculate total salary by team
team_salary = nba.groupby('Team')['Salary'].sum().reset_index().sort_values(by='Salary', ascending=False)

# Plot total salary by team
plt.figure(figsize=(10, 8))
sns.barplot(x='Salary', y='Team', data=team_salary, palette='coolwarm')
plt.title('Total Salary Distribution Among NBA Teams')
plt.xlabel('Total Salary')
plt.ylabel('Team')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-15-49ff2ab4c8b7>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Salary', y='Team', data=team_salary, palette='coolwarm')

# %% [markdown]
# The visualization above displays the total salary distribution among NBA teams, with teams sorted by their total salary expenditure. This bar plot reveals which teams are the biggest spenders on player salaries and which are more conservative. The color gradient provides a visual cue to easily distinguish between the higher and lower spending teams.

# %% [markdown]
# ## Player Age Distribution
#
# Next, let's explore the Player Age Distribution across the NBA. We'll create a histogram to visualize how player ages are distributed, which will help us understand if the league trends younger, older, or has a balanced age mix. ​​

# %%
# Convert 'Birthday' column to datetime format
from dateutil import parser
nba['Birthday'] = nba['Birthday'].apply(lambda x: parser.parse(x))

# Now, let's calculate the age of each player
nba['Age'] = (datetime.now() - nba['Birthday']).dt.days // 365

# Plot the age distribution of NBA players
plt.figure(figsize=(10, 6))
sns.histplot(nba['Age'], bins=15, kde=True, color='skyblue')
plt.title('Age Distribution of NBA Players')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The histogram above shows the age distribution of NBA players, with a kernel density estimate (KDE) overlay to indicate the distribution shape. The majority of players fall within a certain age range, illustrating the league's age dynamics. The plot helps identify the common ages for NBA players and whether there are significant numbers of very young or older players.

# %% [markdown]
# ## Position-wise Salary Insights
#
#
# Moving on to Position-wise Salary Insights, we'll examine how average salaries differ across player positions. This analysis could reveal which positions are typically higher-paid, potentially reflecting their value on the basketball court. Let's create a box plot to visualize the salary distribution for each position. ​​

# %%
# Plot salary distribution by player position
plt.figure(figsize=(10, 6))
sns.boxplot(x='Position', y='Salary', data=nba, palette='Set2')
plt.title('Salary Distribution by Position')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.show()
# Out:
# <ipython-input-24-64923db0a091>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Position', y='Salary', data=nba, palette='Set2')

# %% [markdown]
# The box plot above illustrates the salary distribution by player position, showcasing the variation in salaries among different positions within the NBA. This visualization helps us understand which positions tend to have higher median salaries and the spread of salaries within each position, including outliers that represent exceptionally high or low salaries.

# %% [markdown]
# ## Top 10 Highest Paid Players
#
# Lastly, we'll identify the Top 10 Highest Paid Players in the NBA. This analysis highlights the star earners of the league, providing insights into which players command the highest salaries and potentially why. Let's extract and visualize this information. ​​

# %%
# Identify the top 10 highest paid players
top_10_salaries = nba.sort_values(by='Salary', ascending=False).head(10)

# Plot the top 10 highest paid players
plt.figure(figsize=(12, 8))
sns.barplot(x='Salary', y='Name', data=top_10_salaries, palette='viridis')
plt.title('Top 10 Highest Paid NBA Players')
plt.xlabel('Salary')
plt.ylabel('Player')
plt.show()
# Out:
# <ipython-input-26-67eb9e43cc71>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Salary', y='Name', data=top_10_salaries, palette='viridis')

# %% [markdown]
# The bar plot above reveals the top 10 highest-paid NBA players, showcasing those who stand at the pinnacle of the league in terms of salary. This visualization not only highlights the star players who command the highest salaries but also may reflect their marketability, performance, and contribution to their respective teams.
